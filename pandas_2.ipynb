# %%
import pandas as pd
d2=pd.read_csv("C:/Users/saibh/OneDrive/Documents/school.csv")
d2
# Out:
#    StudentID     Name Gender  Math  Science  English  Attendance  GradeLevel
# 0          1    Alice      F    78       88       85          92          10
# 1          2      Bob      M    67       77       70          85          10
# 2          3  Charlie      M    90       93       89          95          11
# 3          4    David      M    55       60       58          72          11
# 4          5      Eva      F    82       79       88          98          12
# 5          6    Frank      M    45       50       52          60          12
# 6          7    Grace      F    92       95       94          99          10
# 7          8   Hannah      F    75       77       72          85          11

# %%
d2.insert(5,"Chemistry",[87,78,65,79,89,85,90,82])
d2
# Out:
#    StudentID     Name Gender  Math  Science  Chemistry  English  Attendance  \
# 0          1    Alice      F    78       88         87       85          92
# 1          2      Bob      M    67       77         78       70          85
# 2          3  Charlie      M    90       93         65       89          95
# 3          4    David      M    55       60         79       58          72
# 4          5      Eva      F    82       79         89       88          98
# 5          6    Frank      M    45       50         85       52          60
# 6          7    Grace      F    92       95         90       94          99
# 7          8   Hannah      F    75       77         82       72          85
#
#    GradeLevel
# 0          10
# 1          10
# 2          11
# 3          11
# 4          12
# 5          12
# 6          10
# 7          11

# %%
d2.insert(7, "Total", d2[["Math", "Science", "Chemistry", "English"]].sum(axis=1))
d2
# Out:
#    StudentID     Name Gender  Math  Science  Chemistry  English  Total  \
# 0          1    Alice      F    78       88         87       85    338
# 1          2      Bob      M    67       77         78       70    292
# 2          3  Charlie      M    90       93         65       89    337
# 3          4    David      M    55       60         79       58    252
# 4          5      Eva      F    82       79         89       88    338
# 5          6    Frank      M    45       50         85       52    232
# 6          7    Grace      F    92       95         90       94    371
# 7          8   Hannah      F    75       77         82       72    306
#
#    Attendance  GradeLevel
# 0          92          10
# 1          85          10
# 2          95          11
# 3          72          11
# 4          98          12
# 5          60          12
# 6          99          10
# 7          85          11

# %%
d2.sort_values("Total",ascending=False)
d2
# Out:
#    StudentID     Name Gender  Math  Science  Chemistry  English  Total  \
# 0          1    Alice      F    78       88         87       85    338
# 1          2      Bob      M    67       77         78       70    292
# 2          3  Charlie      M    90       93         65       89    337
# 3          4    David      M    55       60         79       58    252
# 4          5      Eva      F    82       79         89       88    338
# 5          6    Frank      M    45       50         85       52    232
# 6          7    Grace      F    92       95         90       94    371
# 7          8   Hannah      F    75       77         82       72    306
#
#    Attendance  GradeLevel
# 0          92          10
# 1          85          10
# 2          95          11
# 3          72          11
# 4          98          12
# 5          60          12
# 6          99          10
# 7          85          11

# %%
d2
# Out:
#    StudentID     Name Gender  Math  Science  Chemistry  English  Total  \
# 0          1    Alice      F    78       88         87       85    338
# 1          2      Bob      M    67       77         78       70    292
# 2          3  Charlie      M    90       93         65       89    337
# 3          4    David      M    55       60         79       58    252
# 4          5      Eva      F    82       79         89       88    338
# 5          6    Frank      M    45       50         85       52    232
# 6          7    Grace      F    92       95         90       94    371
# 7          8   Hannah      F    75       77         82       72    306
#
#    Attendance  GradeLevel
# 0          92          10
# 1          85          10
# 2          95          11
# 3          72          11
# 4          98          12
# 5          60          12
# 6          99          10
# 7          85          11

# %%
d2.sort_values("Total",ascending=False)
# Out:
#    StudentID     Name Gender  Math  Science  Chemistry  English  Total  \
# 6          7    Grace      F    92       95         90       94    371
# 0          1    Alice      F    78       88         87       85    338
# 4          5      Eva      F    82       79         89       88    338
# 2          3  Charlie      M    90       93         65       89    337
# 7          8   Hannah      F    75       77         82       72    306
# 1          2      Bob      M    67       77         78       70    292
# 3          4    David      M    55       60         79       58    252
# 5          6    Frank      M    45       50         85       52    232
#
#    Attendance  GradeLevel
# 6          99          10
# 0          92          10
# 4          98          12
# 2          95          11
# 7          85          11
# 1          85          10
# 3          72          11
# 5          60          12

# %%
d2
# Out:
#    StudentID     Name Gender  Math  Science  Chemistry  English  Total  \
# 0          1    Alice      F    78       88         87       85    338
# 1          2      Bob      M    67       77         78       70    292
# 2          3  Charlie      M    90       93         65       89    337
# 3          4    David      M    55       60         79       58    252
# 4          5      Eva      F    82       79         89       88    338
# 5          6    Frank      M    45       50         85       52    232
# 6          7    Grace      F    92       95         90       94    371
# 7          8   Hannah      F    75       77         82       72    306
#
#    Attendance  GradeLevel
# 0          92          10
# 1          85          10
# 2          95          11
# 3          72          11
# 4          98          12
# 5          60          12
# 6          99          10
# 7          85          11

# %%
d2[(d2["Gender"]=="F")]
# Out:
#    StudentID    Name Gender  Math  Science  Chemistry  English  Total  \
# 0          1   Alice      F    78       88         87       85    338
# 4          5     Eva      F    82       79         89       88    338
# 6          7   Grace      F    92       95         90       94    371
# 7          8  Hannah      F    75       77         82       72    306
#
#    Attendance  GradeLevel
# 0          92          10
# 4          98          12
# 6          99          10
# 7          85          11
